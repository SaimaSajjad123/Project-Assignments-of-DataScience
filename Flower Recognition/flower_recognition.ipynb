# %%
import os, shutil,matplotlib.pyplot as plt,numpy as np
import numpy as np
import random

# %%
path=os.getcwd()
dataset=os.path.join(path,'.\\Datasets\\flowers-recognition\\flowers\\')
files=os.listdir(dataset)
dataset
# Out:
# 'C:\\Users\\dell\\Data-Science\\.\\Datasets\\flowers-recognition\\flowers\\'

# %%
plt.figure(1 , figsize = (15 , 9))
n = 0 
for i in range(49):
    n += 1 
    r = np.random.randint(0 , data.shape[0] , 1)
    plt.subplot(7 , 7 , n)
    plt.subplots_adjust(hspace = 0.5 , wspace = 0.5)
    plt.imshow(data[r[0]])
    plt.title('{} : {}'.format('Label1' if labels[r[0]]==1 else 'Label2', labels[r[0]]))
    plt.xticks([]) , plt.yticks([])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-e9528b579a01> in <module>
#       3 for i in range(49):
#       4     n += 1
# ----> 5     r = np.random.randint(0 , data.shape[0] , 1)
#       6     plt.subplot(7 , 7 , n)
#       7     plt.subplots_adjust(hspace = 0.5 , wspace = 0.5)
#
# NameError: name 'data' is not defined

# %%
#Directories Creation
original_dataset_dir = '.\\Datasets\\flowers-recognition\\flowers'

base_dir = '.\\Datasets\\flowers-recognition\\flowers\\prepared'

if (not(os.path.exists(base_dir))):
    os.mkdir(base_dir)


train_dir = os.path.join(base_dir, 'train')
#os.mkdir(train_dir)
validation_dir = os.path.join(base_dir, 'validation')
#os.mkdir(validation_dir)
test_dir = os.path.join(base_dir, 'test')
#os.mkdir(test_dir)
'''
# Directory with our training daisy pictures
train_obj1_dir = os.path.join(train_dir, 'daisy')
os.mkdir(train_obj1_dir)

# Directory with our training dandelion pictures
train_obj2_dir = os.path.join(train_dir, 'dandelion')
os.mkdir(train_obj2_dir)

# Directory with our training rose pictures
train_obj3_dir = os.path.join(train_dir, 'rose')
os.mkdir(train_obj3_dir)

# Directory with our training sunflower pictures
train_obj4_dir = os.path.join(train_dir, 'sunflower')
os.mkdir(train_obj4_dir)

# Directory with our training tulip pictures
train_obj5_dir = os.path.join(train_dir, 'tulip')
os.mkdir(train_obj5_dir)

# Directory with our validation daisy pictures
validation_obj1_dir = os.path.join(validation_dir, 'daisy')
os.mkdir(validation_obj1_dir)

# Directory with our validation dandelion pictures
validation_obj2_dir = os.path.join(validation_dir, 'dandelion')
os.mkdir(validation_obj2_dir)

# Directory with our validation rose pictures
validation_obj3_dir = os.path.join(validation_dir, 'rose')
os.mkdir(validation_obj3_dir)

# Directory with our validation sunflower pictures
validation_obj4_dir = os.path.join(validation_dir, 'sunflower')
os.mkdir(validation_obj4_dir)

# Directory with our validation tulip pictures
validation_obj5_dir = os.path.join(validation_dir, 'tulip')
os.mkdir(validation_obj5_dir)

# Directory with our test daisy pictures
test_obj1_dir = os.path.join(test_dir, 'daisy')
os.mkdir(test_obj1_dir)

# Directory with our test dandelion pictures
test_obj2_dir = os.path.join(test_dir, 'dandelion')
os.mkdir(test_obj2_dir)

# Directory with our test rose pictures
test_obj3_dir = os.path.join(test_dir, 'rose')
os.mkdir(test_obj3_dir)

# Directory with our test sunflower pictures
test_obj4_dir = os.path.join(test_dir, 'sunflower')
os.mkdir(test_obj4_dir)

# Directory with our test tulip pictures
test_obj5_dir = os.path.join(test_dir, 'tulip')
os.mkdir(test_obj5_dir)  '''
# Out:
# "\n# Directory with our training daisy pictures\ntrain_obj1_dir = os.path.join(train_dir, 'daisy')\nos.mkdir(train_obj1_dir)\n\n# Directory with our training dandelion pictures\ntrain_obj2_dir = os.path.join(train_dir, 'dandelion')\nos.mkdir(train_obj2_dir)\n\n# Directory with our training rose pictures\ntrain_obj3_dir = os.path.join(train_dir, 'rose')\nos.mkdir(train_obj3_dir)\n\n# Directory with our training sunflower pictures\ntrain_obj4_dir = os.path.join(train_dir, 'sunflower')\nos.mkdir(train_obj4_dir)\n\n# Directory with our training tulip pictures\ntrain_obj5_dir = os.path.join(train_dir, 'tulip')\nos.mkdir(train_obj5_dir)\n\n# Directory with our validation daisy pictures\nvalidation_obj1_dir = os.path.join(validation_dir, 'daisy')\nos.mkdir(validation_obj1_dir)\n\n# Directory with our validation dandelion pictures\nvalidation_obj2_dir = os.path.join(validation_dir, 'dandelion')\nos.mkdir(validation_obj2_dir)\n\n# Directory with our validation rose pictures\nvalidation_obj3_d
# ...

# %%
#Copying Images
folder=os.listdir(original_dataset_dir)

'''
daisy_imgs=os.path.join(dataset,folder[0])
Daisy_Imgs=os.listdir(daisy_imgs)
img_list=random.sample(Daisy_Imgs, len(Daisy_Imgs))

# Copy 461 daisy images to train_obj1_dir
fnames = [img_list[i].format(i) for i in range(461)]
for fname in fnames:
    src = os.path.join(daisy_imgs,fname)
    dst = os.path.join(train_obj1_dir,fname)
    shutil.copyfile(src, dst)


# Copy 154 daisy  images to validation_obj1_dir
fnames = [img_list[i].format(i) for i in range(461,615)]
for fname in fnames:
    src = os.path.join(daisy_imgs, fname)
    dst = os.path.join(validation_obj1_dir, fname)
    shutil.copyfile(src, dst)

# Copy 154 daisy images to test_obj1_dir
fnames = [img_list[i].format(i) for i in range(615,769)]
for fname in fnames:
    src = os.path.join(daisy_imgs, fname)
    dst = os.path.join(test_obj1_dir, fname)
    shutil.copyfile(src, dst)

print("Daisy (Train/Test) Completed.")



dandelion_imgs=os.path.join(dataset,folder[1])
Dandelion_Imgs=os.listdir(dandelion_imgs)
img_list=random.sample(Dandelion_Imgs, len(Dandelion_Imgs))

# Copy 633 dandelion images to train_obj2_dir
fnames = [img_list[i].format(i) for i in range(633)]
for fname in fnames:
    src = os.path.join(dandelion_imgs,fname)
    dst = os.path.join(train_obj2_dir,fname)
    shutil.copyfile(src, dst)


# Copy 211 dandelion  images to validation_obj2_dir
fnames = [img_list[i].format(i) for i in range(633,844)]
for fname in fnames:
    src = os.path.join(dandelion_imgs, fname)
    dst = os.path.join(validation_obj2_dir, fname)
    shutil.copyfile(src, dst)

# Copy 211 dandelion images to test_obj2_dir
fnames = [img_list[i].format(i) for i in range(844,1055)]
for fname in fnames:
    src = os.path.join(dandelion_imgs, fname)
    dst = os.path.join(test_obj2_dir, fname)
    shutil.copyfile(src, dst)

print("Dandelion (Train/Test) Completed.")


rose_imgs=os.path.join(dataset,folder[3])
Rose_Imgs=os.listdir(rose_imgs)
img_list=random.sample(Rose_Imgs, len(Rose_Imgs))

# Copy 470 rose images to train_obj3_dir
fnames = [img_list[i].format(i) for i in range(470)]
for fname in fnames:
    src = os.path.join(rose_imgs,fname)
    dst = os.path.join(train_obj3_dir,fname)
    shutil.copyfile(src, dst)


# Copy 154 rose dandelion  images to validation_obj3_dir
fnames = [img_list[i].format(i) for i in range(470,627)]
for fname in fnames:
    src = os.path.join(rose_imgs, fname)
    dst = os.path.join(validation_obj3_dir, fname)
    shutil.copyfile(src, dst)

# Copy 154 rose images to test_obj3_dir
fnames = [img_list[i].format(i) for i in range(627,784)]
for fname in fnames:
    src = os.path.join(rose_imgs, fname)
    dst = os.path.join(test_obj3_dir, fname)
    shutil.copyfile(src, dst)

print("Rose (Train/Test) Completed.")


sunflower_imgs=os.path.join(dataset,folder[4])
Sunflower_Imgs=os.listdir(sunflower_imgs)
img_list=random.sample(Sunflower_Imgs, len(Sunflower_Imgs))

# Copy 440 sunflower images to train_obj3_dir
fnames = [img_list[i].format(i) for i in range(440)]
for fname in fnames:
    src = os.path.join(sunflower_imgs,fname)
    dst = os.path.join(train_obj4_dir,fname)
    shutil.copyfile(src, dst)


# Copy 147 sunflower  dandelion  images to validation_obj3_dir
fnames = [img_list[i].format(i) for i in range(440,587)]
for fname in fnames:
    src = os.path.join(sunflower_imgs, fname)
    dst = os.path.join(validation_obj4_dir, fname)
    shutil.copyfile(src, dst)

# Copy 147 sunflower  images to test_obj3_dir
fnames = [img_list[i].format(i) for i in range(587,734)]
for fname in fnames:
    src = os.path.join(sunflower_imgs, fname)
    dst = os.path.join(test_obj4_dir, fname)
    shutil.copyfile(src, dst)

print("Sunflower (Train/Test) Completed.")


tulip_imgs=os.path.join(dataset,folder[5])
Tulip_Imgs=os.listdir(tulip_imgs)
img_list=random.sample(Tulip_Imgs, len(Tulip_Imgs))

# Copy 590 tulip images to train_obj3_dir
fnames = [img_list[i].format(i) for i in range(590)]
for fname in fnames:
    src = os.path.join(tulip_imgs,fname)
    dst = os.path.join(train_obj5_dir,fname)
    shutil.copyfile(src, dst)


# Copy 197 tulip dandelion  images to validation_obj3_dir
fnames = [img_list[i].format(i) for i in range(590,787)]
for fname in fnames:
    src = os.path.join(tulip_imgs, fname)
    dst = os.path.join(validation_obj5_dir, fname)
    shutil.copyfile(src, dst)

# Copy 197 tulip images to test_obj3_dir
fnames = [img_list[i].format(i) for i in range(787,984)]
for fname in fnames:
    src = os.path.join(tulip_imgs, fname)
    dst = os.path.join(test_obj5_dir, fname)
    shutil.copyfile(src, dst)

print("Tulip (Train/Test) Completed")'''
# Out:
# ['daisy', 'dandelion', 'prepared', 'rose', 'sunflower', 'tulip']
# ...

# %%
#PLotting
import pandas as pd
daisylen=(len(os.listdir(dataset+"\\daisy")))
dandlen=(len(os.listdir(dataset+"\\dandelion")))
roselen=(len(os.listdir(dataset+"\\rose")))
sunflowerlen=(len(os.listdir(dataset+"\\sunflower")))
tuliplen=(len(os.listdir(dataset+"\\tulip")))

fig, ax = plt.subplots()

df_list=[daisylen,dandlen,roselen,sunflowerlen,tuliplen]
labels=['daisy','dandelion','rose','sunflower','tulip']
#df = pd.DataFrame(df_list,index=labels)


x = np.arange(len(labels)) 
width = 0.35 

ax.set_xticklabels(labels)
ax.set_xticks(x)
ax.bar(x - width/2,df_list,width)

#df[0].value_counts().plot(kind='bar',color='g')

fig.tight_layout()
plt.show()

# %%
from keras import layers
from keras import models

model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(5, activation='sigmoid'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_13 (Conv2D)           (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 15, 15, 128)       147584
# ...

# %%
from keras import optimizers

model.compile(loss='categorical_crossentropy',
              optimizer=optimizers.RMSprop(lr=1e-4),
              metrics=['acc'])

# %%
from keras.preprocessing.image import ImageDataGenerator

# All images will be rescaled by 1./255
train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        # This is the target directory
        train_dir,
        # All images will be resized to 150x150
        target_size=(150, 150),
        batch_size=20,
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
        validation_dir,
        target_size=(150, 150),
        batch_size=20,
        class_mode='categorical')
# Out:
# Found 2592 images belonging to 5 classes.
# Found 866 images belonging to 5 classes.

# %%
#Prediction
import os
import random
from scipy import ndarray
import matplotlib.image as mpimg

#image processing library
import skimage as sk
from skimage import transform
from skimage import util
from skimage import io

img1=mpimg.imread('t3.jpg')
dirpath=['daisy','dandelion','rose','sunflower','tulip']


import numpy as np
img = sk.io.imread('t3.jpg')
img = sk.transform.resize(img,(150,150))
img = np.reshape(img,[1,150,150,3])
classes = model.predict(img)
plt.title('t3.jpg')
plt.imshow(img1)
plt.show()
print(dirpath[np.argmax(classes)])
# Out:
# sunflower
